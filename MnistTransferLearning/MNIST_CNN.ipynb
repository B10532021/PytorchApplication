# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import torch.nn.functional as F
import torch.utils.data as Data
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import copy

# %matplotlib inline

use_cuda = torch.cuda.is_available()
if use_cuda:
    print('cuda available')
    
dtype = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
itype = torch.cuda.LongTensor if use_cuda else torch.LongTensor

# Hyper Parameters
IMG_SIZE = 28 * 28
NUM_CLASSES = 10
NUM_EPOCHS = 20
BATCH_SIZE = 64
LR = 0.001

# load data
train_dataset = datasets.MNIST(
    root = './data',
    train = True,
    transform = transforms.ToTensor(),
    download = False,
)

test_dataset = datasets.MNIST(
    root = './data',
    train = False,
    transform = transforms.ToTensor(),
)

train_loader = Data.DataLoader(
    dataset = train_dataset,
    batch_size = BATCH_SIZE,
    shuffle = True,
)

test_loader = Data.DataLoader(
    dataset = test_dataset,
    batch_size = BATCH_SIZE,
    shuffle = True
)

test_x = Variable(torch.unsqueeze(test_dataset.test_data, dim = 1)).type(torch.FloatTensor)[:2000]/255
test_y = test_dataset.test_labels[:2000]
# Out:
# cuda available

# %%
# model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(
                in_channels = 1,
                out_channels = 16, 
                kernel_size = 5,
                stride = 1,
                padding = 2,
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2),
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(
                in_channels = 16,
                out_channels = 32,
                kernel_size = 5,
                stride = 1,
                padding = 2,
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2)
        )
        self.out = nn.Linear(32 * 7 * 7, 10)
    
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), -1)
        output = self.out(x)
        output = F.log_softmax(output, dim = 1)
        return output
    
    def retrieve_features(self, x):
        feature_map1 = self.conv1(x)
        feature_map2 = self.conv2(feature_map1)
        return(feature_map1, feature_map2)

# %%
# train
def rightness(predictions, labels):
    pred = torch.max(predictions.data, 1)[1]
    rights = pred.eq(labels.data.view_as(pred)).sum()
    return rights * 100 / len(labels)

net = CNN()

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr = LR)

for epoch in range(NUM_EPOCHS):
    for step, (x, y) in enumerate(train_loader):
        X = Variable(x)
        Y = Variable(y)
        
        net.train()
        output = net(X)
        loss = criterion(output, Y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if step % 100 == 0:
            net.eval()
            test_output = net(test_x)
            rights = rightness(test_output, test_y)
            print('Epoch: ', epoch, '| train loss: %.4f' % loss.data.numpy(), '| test accuracy: %.2f' % rights)
# Out:
# Epoch:  0 | train loss: 2.3074 | test accuracy: 11.00
# Epoch:  0 | train loss: 0.2399 | test accuracy: 91.00
# Epoch:  0 | train loss: 0.3387 | test accuracy: 94.00
# Epoch:  0 | train loss: 0.1227 | test accuracy: 95.00
# Epoch:  0 | train loss: 0.2630 | test accuracy: 96.00
# Epoch:  0 | train loss: 0.1941 | test accuracy: 96.00
# Epoch:  0 | train loss: 0.0240 | test accuracy: 96.00
# Epoch:  0 | train loss: 0.0262 | test accuracy: 97.00
# Epoch:  0 | train loss: 0.0581 | test accuracy: 97.00
# Epoch:  0 | train loss: 0.1611 | test accuracy: 97.00
# Epoch:  1 | train loss: 0.0762 | test accuracy: 97.00
# Epoch:  1 | train loss: 0.0069 | test accuracy: 97.00
# Epoch:  1 | train loss: 0.0954 | test accuracy: 97.00
# Epoch:  1 | train loss: 0.0549 | test accuracy: 98.00
# Epoch:  1 | train loss: 0.0203 | test accuracy: 97.00
# Epoch:  1 | train loss: 0.0676 | test accuracy: 98.00
# Epoch:  1 | train loss: 0.0660 | test accuracy: 98.00
# Epoch:  1 | train loss: 0.0197 | test accuracy: 98.00
# Epoch:  1 | train loss: 0.1271 | test accuracy: 98.00
# Epoch:  1 | train loss: 0.0076 | test accuracy: 98.00
# Epoch:  2 | train loss: 0.0415 | test accuracy: 98.00
# Epoch:  2 | train loss: 0.0199 | test accuracy: 98.00
# Epoch:  2 | train loss: 0.0441 | test accuracy: 98.00
# Epoch:  2 | train loss: 0.0146 | test accuracy: 98.00
# Epoch:  2 | train loss: 0.0297 | test accuracy: 98.00
# Epoch:  2 | train loss: 0.0187 | test accuracy: 98.00
# Epoch:  2 | train loss: 0.0978 | test accuracy: 98.00
# Epoch:  2 | train loss: 0.0074 | test accuracy: 98.00
# Epoch:  2 | train loss: 0.0303 | test accuracy: 98.00
# Epoch:  2 | train loss: 0.0024 | test accuracy: 98.00
# Epoch:  3 | train loss: 0.0112 | test accuracy: 98.00
# Epoch:  3 | train loss: 0.0257 | test accuracy: 98.00
# Epoch:  3 | train loss: 0.0044 | test accuracy: 98.00
# Epoch:  3 | train loss: 0.0534 | test accuracy: 98.00
# Epoch:  3 | train loss: 0.0134 | test accuracy: 98.00
# Epoch:  3 | train loss: 0.0302 | test accuracy: 98.00
# Epoch:  3 | train loss: 0.0048 | test accuracy: 98.00
# Epoch:  3 | train loss: 0.0602 | test accuracy: 98.00
# Epoch:  3 | train loss: 0.0153 | test accuracy: 98.00
# Epoch:  3 | train loss: 0.0158 | test accuracy: 98.00
# Epoch:  4 | train loss: 0.0249 | test accuracy: 98.00
# Epoch:  4 | train loss: 0.0360 | test accuracy: 98.00
# Epoch:  4 | train loss: 0.0058 | test accuracy: 98.00
# Epoch:  4 | train loss: 0.0368 | test accuracy: 98.00
# Epoch:  4 | train loss: 0.0035 | test accuracy: 98.00
# Epoch:  4 | train loss: 0.0236 | test accuracy: 98.00
# Epoch:  4 | train loss: 0.0032 | test accuracy: 98.00
# Epoch:  4 | train loss: 0.0202 | test accuracy: 98.00
# Epoch:  4 | train loss: 0.0070 | test accuracy: 98.00
# Epoch:  4 | train loss: 0.0104 | test accuracy: 98.00
# Epoch:  5 | train loss: 0.0152 | test accuracy: 98.00
# Epoch:  5 | train loss: 0.0023 | test accuracy: 98.00
# Epoch:  5 | train loss: 0.0031 | test accuracy: 98.00
# Epoch:  5 | train loss: 0.0243 | test accuracy: 98.00
# Epoch:  5 | train loss: 0.0306 | test accuracy: 98.00
# Epoch:  5 | train loss: 0.0065 | test accuracy: 98.00
# Epoch:  5 | train loss: 0.0062 | test accuracy: 98.00
# Epoch:  5 | train loss: 0.0055 | test accuracy: 98.00
# Epoch:  5 | train loss: 0.0033 | test accuracy: 98.00
# Epoch:  5 | train loss: 0.0009 | test accuracy: 98.00
# Epoch:  6 | train loss: 0.0015 | test accuracy: 98.00
# Epoch:  6 | train loss: 0.0251 | test accuracy: 98.00
# Epoch:  6 | train loss: 0.0096 | test accuracy: 98.00
# Epoch:  6 | train loss: 0.0333 | test accuracy: 98.00
# Epoch:  6 | train loss: 0.0030 | test accuracy: 98.00
# Epoch:  6 | train loss: 0.0252 | test accuracy: 98.00
# Epoch:  6 | train loss: 0.0053 | test accuracy: 98.00
# Epoch:  6 | train loss: 0.0012 | test accuracy: 98.00
# Epoch:  6 | train loss: 0.0564 | test accuracy: 98.00
# Epoch:  6 | train loss: 0.0020 | test accuracy: 98.00
# Epoch:  7 | train loss: 0.0007 | test accuracy: 98.00
# Epoch:  7 | train loss: 0.0177 | test accuracy: 99.00
# Epoch:  7 | train loss: 0.0133 | test accuracy: 98.00
# Epoch:  7 | train loss: 0.0017 | test accuracy: 98.00
# Epoch:  7 | train loss: 0.0023 | test accuracy: 98.00
# Epoch:  7 | train loss: 0.0146 | test accuracy: 98.00
# Epoch:  7 | train loss: 0.0024 | test accuracy: 98.00
# Epoch:  7 | train loss: 0.0162 | test accuracy: 98.00
# Epoch:  7 | train loss: 0.0056 | test accuracy: 98.00
# Epoch:  7 | train loss: 0.0005 | test accuracy: 98.00
# Epoch:  8 | train loss: 0.0001 | test accuracy: 98.00
# Epoch:  8 | train loss: 0.0062 | test accuracy: 98.00
# Epoch:  8 | train loss: 0.0000 | test accuracy: 98.00
# Epoch:  8 | train loss: 0.0360 | test accuracy: 98.00
# Epoch:  8 | train loss: 0.0201 | test accuracy: 98.00
# Epoch:  8 | train loss: 0.0091 | test accuracy: 98.00
# Epoch:  8 | train loss: 0.0015 | test accuracy: 98.00
# Epoch:  8 | train loss: 0.0207 | test accuracy: 98.00
# Epoch:  8 | train loss: 0.0007 | test accuracy: 98.00
# Epoch:  8 | train loss: 0.0020 | test accuracy: 99.00
# Epoch:  9 | train loss: 0.0295 | test accuracy: 98.00
# Epoch:  9 | train loss: 0.0021 | test accuracy: 98.00
# Epoch:  9 | train loss: 0.0035 | test accuracy: 99.00
# Epoch:  9 | train loss: 0.0002 | test accuracy: 98.00
# Epoch:  9 | train loss: 0.0009 | test accuracy: 99.00
# Epoch:  9 | train loss: 0.0024 | test accuracy: 98.00
# Epoch:  9 | train loss: 0.0135 | test accuracy: 98.00
# Epoch:  9 | train loss: 0.0004 | test accuracy: 98.00
# Epoch:  9 | train loss: 0.0010 | test accuracy: 98.00
# Epoch:  9 | train loss: 0.0011 | test accuracy: 98.00
# Epoch:  10 | train loss: 0.0113 | test accuracy: 98.00
# Epoch:  10 | train loss: 0.0005 | test accuracy: 98.00
# Epoch:  10 | train loss: 0.0012 | test accuracy: 98.00
# Epoch:  10 | train loss: 0.0062 | test accuracy: 98.00
# Epoch:  10 | train loss: 0.0011 | test accuracy: 98.00
# Epoch:  10 | train loss: 0.0008 | test accuracy: 98.00
# Epoch:  10 | train loss: 0.0001 | test accuracy: 98.00
# Epoch:  10 | train loss: 0.0008 | test accuracy: 99.00
# Epoch:  10 | train loss: 0.0001 | test accuracy: 99.00
# Epoch:  10 | train loss: 0.0787 | test accuracy: 98.00
# Epoch:  11 | train loss: 0.0431 | test accuracy: 98.00
# Epoch:  11 | train loss: 0.0040 | test accuracy: 98.00
# Epoch:  11 | train loss: 0.0010 | test accuracy: 99.00
# Epoch:  11 | train loss: 0.0023 | test accuracy: 99.00
# Epoch:  11 | train loss: 0.0021 | test accuracy: 99.00
# Epoch:  11 | train loss: 0.0009 | test accuracy: 98.00
# Epoch:  11 | train loss: 0.0010 | test accuracy: 99.00
# Epoch:  11 | train loss: 0.0124 | test accuracy: 98.00
# Epoch:  11 | train loss: 0.0000 | test accuracy: 99.00
# Epoch:  11 | train loss: 0.0443 | test accuracy: 99.00
# Epoch:  12 | train loss: 0.0001 | test accuracy: 98.00
# Epoch:  12 | train loss: 0.0447 | test accuracy: 99.00
# Epoch:  12 | train loss: 0.0005 | test accuracy: 98.00
# Epoch:  12 | train loss: 0.0260 | test accuracy: 98.00
# Epoch:  12 | train loss: 0.0235 | test accuracy: 99.00
# Epoch:  12 | train loss: 0.0006 | test accuracy: 99.00
# Epoch:  12 | train loss: 0.0045 | test accuracy: 98.00
# Epoch:  12 | train loss: 0.0001 | test accuracy: 98.00
# Epoch:  12 | train loss: 0.0007 | test accuracy: 98.00
# Epoch:  12 | train loss: 0.0097 | test accuracy: 98.00
# Epoch:  13 | train loss: 0.0018 | test accuracy: 98.00
# Epoch:  13 | train loss: 0.0024 | test accuracy: 98.00
# Epoch:  13 | train loss: 0.0002 | test accuracy: 99.00
# Epoch:  13 | train loss: 0.0008 | test accuracy: 98.00
# Epoch:  13 | train loss: 0.0002 | test accuracy: 99.00
# Epoch:  13 | train loss: 0.0039 | test accuracy: 98.00
# Epoch:  13 | train loss: 0.0055 | test accuracy: 98.00
# Epoch:  13 | train loss: 0.0003 | test accuracy: 98.00
# Epoch:  13 | train loss: 0.0009 | test accuracy: 98.00
# Epoch:  13 | train loss: 0.0017 | test accuracy: 99.00
# Epoch:  14 | train loss: 0.0007 | test accuracy: 99.00
# Epoch:  14 | train loss: 0.0001 | test accuracy: 98.00
# Epoch:  14 | train loss: 0.0014 | test accuracy: 98.00
# Epoch:  14 | train loss: 0.0021 | test accuracy: 98.00
# Epoch:  14 | train loss: 0.0002 | test accuracy: 98.00
# Epoch:  14 | train loss: 0.0002 | test accuracy: 99.00
# Epoch:  14 | train loss: 0.0025 | test accuracy: 98.00
# Epoch:  14 | train loss: 0.0055 | test accuracy: 99.00
# Epoch:  14 | train loss: 0.0259 | test accuracy: 98.00
# Epoch:  14 | train loss: 0.0001 | test accuracy: 99.00
# Epoch:  15 | train loss: 0.0066 | test accuracy: 99.00
# Epoch:  15 | train loss: 0.0002 | test accuracy: 99.00
# Epoch:  15 | train loss: 0.0000 | test accuracy: 99.00
# Epoch:  15 | train loss: 0.0000 | test accuracy: 99.00
# Epoch:  15 | train loss: 0.0001 | test accuracy: 99.00
# Epoch:  15 | train loss: 0.0003 | test accuracy: 98.00
# Epoch:  15 | train loss: 0.0054 | test accuracy: 99.00
# Epoch:  15 | train loss: 0.0039 | test accuracy: 98.00
# Epoch:  15 | train loss: 0.0001 | test accuracy: 98.00
# Epoch:  15 | train loss: 0.0136 | test accuracy: 99.00
# Epoch:  16 | train loss: 0.0000 | test accuracy: 98.00
# Epoch:  16 | train loss: 0.0002 | test accuracy: 98.00
# Epoch:  16 | train loss: 0.0269 | test accuracy: 98.00
# Epoch:  16 | train loss: 0.0004 | test accuracy: 98.00
# Epoch:  16 | train loss: 0.0359 | test accuracy: 98.00
# Epoch:  16 | train loss: 0.0003 | test accuracy: 98.00
# Epoch:  16 | train loss: 0.0000 | test accuracy: 98.00
# Epoch:  16 | train loss: 0.0272 | test accuracy: 99.00
# Epoch:  16 | train loss: 0.0001 | test accuracy: 98.00
# Epoch:  16 | train loss: 0.0004 | test accuracy: 98.00
# Epoch:  17 | train loss: 0.0237 | test accuracy: 98.00
# Epoch:  17 | train loss: 0.0000 | test accuracy: 98.00
# Epoch:  17 | train loss: 0.0000 | test accuracy: 98.00
# Epoch:  17 | train loss: 0.0014 | test accuracy: 98.00
# Epoch:  17 | train loss: 0.0007 | test accuracy: 98.00
# Epoch:  17 | train loss: 0.0004 | test accuracy: 99.00
# Epoch:  17 | train loss: 0.0123 | test accuracy: 98.00
# Epoch:  17 | train loss: 0.0043 | test accuracy: 98.00
# Epoch:  17 | train loss: 0.0192 | test accuracy: 98.00
# Epoch:  17 | train loss: 0.0085 | test accuracy: 98.00
# Epoch:  18 | train loss: 0.0273 | test accuracy: 98.00
# Epoch:  18 | train loss: 0.0031 | test accuracy: 98.00
# Epoch:  18 | train loss: 0.0134 | test accuracy: 98.00
# Epoch:  18 | train loss: 0.0008 | test accuracy: 98.00
# Epoch:  18 | train loss: 0.0000 | test accuracy: 98.00
# Epoch:  18 | train loss: 0.0000 | test accuracy: 98.00
# Epoch:  18 | train loss: 0.0001 | test accuracy: 99.00
# Epoch:  18 | train loss: 0.0001 | test accuracy: 98.00
# Epoch:  18 | train loss: 0.0003 | test accuracy: 99.00
# Epoch:  18 | train loss: 0.0300 | test accuracy: 99.00
# Epoch:  19 | train loss: 0.0001 | test accuracy: 98.00
# Epoch:  19 | train loss: 0.0004 | test accuracy: 98.00
# Epoch:  19 | train loss: 0.0019 | test accuracy: 99.00
# Epoch:  19 | train loss: 0.0467 | test accuracy: 98.00
# Epoch:  19 | train loss: 0.0076 | test accuracy: 98.00
# Epoch:  19 | train loss: 0.0001 | test accuracy: 98.00
# Epoch:  19 | train loss: 0.0004 | test accuracy: 98.00
# Epoch:  19 | train loss: 0.0005 | test accuracy: 98.00
# Epoch:  19 | train loss: 0.0006 | test accuracy: 98.00
# Epoch:  19 | train loss: 0.0000 | test accuracy: 98.00

# %%
torch.save(net, 'minst_conv_checkpoint')
# Out:
# /home/dehong/.local/lib/python3.6/site-packages/torch/serialization.py:402: UserWarning: Couldn't retrieve source code for container of type CNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
